# %% [markdown]
# ## What's this TensorFlow business?
#
# You've written a lot of code in this assignment to provide a whole host of neural network functionality. Dropout, Batch Norm, and 2D convolutions are some of the workhorses of deep learning in computer vision. You've also worked hard to make your code efficient and vectorized.
#
# For the last part of this assignment, though, we're going to leave behind your beautiful codebase and instead migrate to one of two popular deep learning frameworks: in this instance, TensorFlow (or PyTorch, if you switch over to that notebook)
#
# #### What is it?
# TensorFlow is a system for executing computational graphs over Tensor objects, with native support for performing backpropogation for its Variables. In it, we work with Tensors which are n-dimensional arrays analogous to the numpy ndarray.
#
# #### Why?
#
# * Our code will now run on GPUs! Much faster training. Writing your own modules to run on GPUs is beyond the scope of this class, unfortunately.
# * We want you to be ready to use one of these frameworks for your project so you can experiment more efficiently than if you were writing every feature you want to use by hand.
# * We want you to stand on the shoulders of giants! TensorFlow and PyTorch are both excellent frameworks that will make your lives a lot easier, and now that you understand their guts, you are free to use them :)
# * We want you to be exposed to the sort of deep learning code you might run into in academia or industry.

# %% [markdown]
# ## How will I learn TensorFlow?
#
# TensorFlow has many excellent tutorials available, including those from [Google themselves](https://www.tensorflow.org/get_started/get_started).
#
# Otherwise, this notebook will walk you through much of what you need to do to train models in TensorFlow. See the end of the notebook for some links to helpful tutorials if you want to learn more or need further clarification on topics that aren't fully explained here.

# %% [markdown]
# ## Load Datasets

# %%
import tensorflow as tf
import numpy as np
import math
import timeit
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from cs231n.data_utils import load_CIFAR10

def get_CIFAR10_data(num_training=49000, num_validation=1000, num_test=10000):
    """
    Load the CIFAR-10 dataset from disk and perform preprocessing to prepare
    it for the two-layer neural net classifier. These are the same steps as
    we used for the SVM, but condensed to a single function.  
    """
    # Load the raw CIFAR-10 data
    cifar10_dir = 'cs231n/datasets/cifar-10-batches-py'
    X_train, y_train, X_test, y_test = load_CIFAR10(cifar10_dir)

    # Subsample the data
    mask = range(num_training, num_training + num_validation)
    X_val = X_train[mask]
    y_val = y_train[mask]
    mask = range(num_training)
    X_train = X_train[mask]
    y_train = y_train[mask]
    mask = range(num_test)
    X_test = X_test[mask]
    y_test = y_test[mask]

    # Normalize the data: subtract the mean image
    mean_image = np.mean(X_train, axis=0)
    X_train -= mean_image
    X_val -= mean_image
    X_test -= mean_image

    return X_train, y_train, X_val, y_val, X_test, y_test


# Invoke the above function to get our data.
X_train, y_train, X_val, y_val, X_test, y_test = get_CIFAR10_data()
print('Train data shape: ', X_train.shape)
print('Train labels shape: ', y_train.shape)
print('Validation data shape: ', X_val.shape)
print('Validation labels shape: ', y_val.shape)
print('Test data shape: ', X_test.shape)
print('Test labels shape: ', y_test.shape)
# Out:
# Train data shape:  (49000, 32, 32, 3)
# Train labels shape:  (49000,)
# Validation data shape:  (1000, 32, 32, 3)
# Validation labels shape:  (1000,)
# Test data shape:  (10000, 32, 32, 3)
# Test labels shape:  (10000,)

# %% [markdown]
# ## Example Model
#
# ### Some useful utilities
#
# . Remember that our image data is initially N x H x W x C, where:
# * N is the number of datapoints
# * H is the height of each image in pixels
# * W is the height of each image in pixels
# * C is the number of channels (usually 3: R, G, B)
#
# This is the right way to represent the data when we are doing something like a 2D convolution, which needs spatial understanding of where the pixels are relative to each other. When we input image data into fully connected affine layers, however, we want each data example to be represented by a single vector -- it's no longer useful to segregate the different channels, rows, and columns of the data.

# %% [markdown]
# ### The example model itself
#
# The first step to training your own model is defining its architecture.
#
# Here's an example of a convolutional neural network defined in TensorFlow -- try to understand what each line is doing, remembering that each layer is composed upon the previous layer. We haven't trained anything yet - that'll come next - for now, we want you to understand how everything gets set up.
#
# In that example, you see 2D convolutional layers (Conv2d), ReLU activations, and fully-connected layers (Linear). You also see the Hinge loss function, and the Adam optimizer being used.
#
# Make sure you understand why the parameters of the Linear layer are 5408 and 10.
#
# ### TensorFlow Details
# In TensorFlow, much like in our previous notebooks, we'll first specifically initialize our variables, and then our network model.

# %%
# clear old variables
tf.reset_default_graph()

# setup input (e.g. the data that changes every batch)
# The first dim is None, and gets sets automatically based on batch size fed in
X = tf.placeholder(tf.float32, [None, 32, 32, 3])
y = tf.placeholder(tf.int64, [None])
is_training = tf.placeholder(tf.bool)

def simple_model(X,y):
    # define our weights (e.g. init_two_layer_convnet)
    
    # setup variables
    Wconv1 = tf.get_variable("Wconv1", shape=[7, 7, 3, 32])
    bconv1 = tf.get_variable("bconv1", shape=[32])
    W1 = tf.get_variable("W1", shape=[5408, 10])
    b1 = tf.get_variable("b1", shape=[10])

    # define our graph (e.g. two_layer_convnet)
    a1 = tf.nn.conv2d(X, Wconv1, strides=[1,2,2,1], padding='VALID') + bconv1
    h1 = tf.nn.relu(a1)
    h1_flat = tf.reshape(h1,[-1,5408])
    y_out = tf.matmul(h1_flat,W1) + b1
    return y_out

y_out = simple_model(X,y)

# define our loss
total_loss = tf.losses.hinge_loss(tf.one_hot(y,10),logits=y_out)
mean_loss = tf.reduce_mean(total_loss)

# define our optimizer
optimizer = tf.train.AdamOptimizer(5e-4) # select optimizer and set learning rate
train_step = optimizer.minimize(mean_loss)

# %% [markdown]
# TensorFlow supports many other layer types, loss functions, and optimizers - you will experiment with these next. Here's the official API documentation for these (if any of the parameters used above were unclear, this resource will also be helpful).
#
# * Layers, Activations, Loss functions : https://www.tensorflow.org/api_guides/python/nn
# * Optimizers: https://www.tensorflow.org/api_guides/python/train#Optimizers
# * BatchNorm: https://www.tensorflow.org/api_docs/python/tf/layers/batch_normalization

# %% [markdown]
# ### Training the model on one epoch
# While we have defined a graph of operations above, in order to execute TensorFlow Graphs, by feeding them input data and computing the results, we first need to create a `tf.Session` object. A session encapsulates the control and state of the TensorFlow runtime. For more information, see the TensorFlow [Getting started](https://www.tensorflow.org/get_started/get_started) guide.
#
# Optionally we can also specify a device context such as `/cpu:0` or `/gpu:0`. For documentation on this behavior see [this TensorFlow guide](https://www.tensorflow.org/tutorials/using_gpu)
#
# You should see a validation loss of around 0.4 to 0.6 and an accuracy of 0.30 to 0.35 below

# %%
def run_model(session, predict, loss_val, Xd, yd,
              epochs=1, batch_size=64, print_every=100,
              training=None, plot_losses=False):
    # have tensorflow compute accuracy
    correct_prediction = tf.equal(tf.argmax(predict,1), y)
    accuracy = tf.reduce_mean(tf.cast(correct_prediction, tf.float32))
    
    # shuffle indicies
    train_indicies = np.arange(Xd.shape[0])
    np.random.shuffle(train_indicies)

    training_now = training is not None
    
    # setting up variables we want to compute (and optimizing)
    # if we have a training function, add that to things we compute
    variables = [mean_loss,correct_prediction,accuracy]
    if training_now:
        variables[-1] = training
    
    # counter 
    iter_cnt = 0
    for e in range(epochs):
        # keep track of losses and accuracy
        correct = 0
        losses = []
        # make sure we iterate over the dataset once
        for i in range(int(math.ceil(Xd.shape[0]/batch_size))):
            # generate indicies for the batch
            start_idx = (i*batch_size)%Xd.shape[0]
            idx = train_indicies[start_idx:start_idx+batch_size]
            
            # create a feed dictionary for this batch
            feed_dict = {X: Xd[idx,:],
                         y: yd[idx],
                         is_training: training_now }
            # get batch size
            actual_batch_size = yd[idx].shape[0]
            
            # have tensorflow compute loss and correct predictions
            # and (if given) perform a training step
            loss, corr, _ = session.run(variables,feed_dict=feed_dict)
            
            # aggregate performance stats
            losses.append(loss*actual_batch_size)
            correct += np.sum(corr)
            
            # print every now and then
            if training_now and (iter_cnt % print_every) == 0:
                print("Iteration {0}: with minibatch training loss = {1:.3g} and accuracy of {2:.2g}"\
                      .format(iter_cnt,loss,np.sum(corr)/actual_batch_size))
            iter_cnt += 1
        total_correct = correct/Xd.shape[0]
        total_loss = np.sum(losses)/Xd.shape[0]
        print("Epoch {2}, Overall loss = {0:.3g} and accuracy of {1:.3g}"\
              .format(total_loss,total_correct,e+1))
        if plot_losses:
            plt.plot(losses)
            plt.grid(True)
            plt.title('Epoch {} Loss'.format(e+1))
            plt.xlabel('minibatch number')
            plt.ylabel('minibatch loss')
            plt.show()
    return total_loss,total_correct

with tf.Session() as sess:
    with tf.device("/gpu:0"): #"/cpu:0" or "/gpu:0" 
        sess.run(tf.global_variables_initializer())
        print('Training')
        run_model(sess,y_out,mean_loss,X_train,y_train,1,64,100,train_step,True)
        print('Validation')
        run_model(sess,y_out,mean_loss,X_val,y_val,1,64)
# Out:
# Training
# Iteration 0: with minibatch training loss = 9.62 and accuracy of 0.078
# Iteration 100: with minibatch training loss = 0.956 and accuracy of 0.25
# Iteration 200: with minibatch training loss = 0.767 and accuracy of 0.23
# Iteration 300: with minibatch training loss = 0.569 and accuracy of 0.42
# Iteration 400: with minibatch training loss = 0.591 and accuracy of 0.3
# Iteration 500: with minibatch training loss = 0.566 and accuracy of 0.33
# Iteration 600: with minibatch training loss = 0.519 and accuracy of 0.39
# Iteration 700: with minibatch training loss = 0.436 and accuracy of 0.36
# Epoch 1, Overall loss = 0.737 and accuracy of 0.306
# Validation
# Epoch 1, Overall loss = 0.458 and accuracy of 0.352

# %% [markdown]
# ## Training a specific model
#
# In this section, we're going to specify a model for you to construct. The goal here isn't to get good performance (that'll be next), but instead to get comfortable with understanding the TensorFlow documentation and configuring your own model.
#
# Using the code provided above as guidance, and using the following TensorFlow documentation, specify a model with the following architecture:
#
# * 7x7 Convolutional Layer with 32 filters and stride of 1
# * ReLU Activation Layer
# * Spatial Batch Normalization Layer (trainable parameters, with scale and centering)
# * 2x2 Max Pooling layer with a stride of 2
# * Affine layer with 1024 output units
# * ReLU Activation Layer
# * Affine layer from 1024 input units to 10 outputs

# %%
# clear old variables
tf.reset_default_graph()

# define our input (e.g. the data that changes every batch)
# The first dim is None, and gets sets automatically based on batch size fed in
X = tf.placeholder(tf.float32, [None, 32, 32, 3])
y = tf.placeholder(tf.int64, [None])
is_training = tf.placeholder(tf.bool)

# define model
def complex_model(X,y,is_training):
    # Define weights
    Wconv = tf.get_variable("Wconv", shape=[7, 7, 3, 32])
    bconv = tf.get_variable("bconv", shape=[32])
    # Spatial batch norm layer
    gamma = tf.get_variable("gamma", shape=[32])
    beta = tf.get_variable("beta", shape=[32])
    # First affine layer
    W1 = tf.get_variable("W1", shape=[8192, 1024])
    b1 = tf.get_variable("b1", shape=[1024])
    # Second affine layer
    W2 = tf.get_variable("W2", shape=[1024, 10])
    b2 = tf.get_variable("b2", shape=[10])
    
    # Define graph
    conv = tf.nn.conv2d(X, Wconv, strides=[1, 1, 1, 1], padding='SAME') + bconv
    relu1 = tf.nn.relu(conv)
    spatial_bn = tf.layers.batch_normalization(relu1, axis=3, epsilon=1e-5, training=is_training, trainable=True)
    mp = tf.nn.max_pool(spatial_bn, ksize=[1, 2, 2, 1], strides=[1, 2, 2, 1], padding='SAME')
    mp_flat = tf.reshape(mp, [-1, 8192])
    aff1 = tf.matmul(mp_flat, W1) + b1
    relu2 = tf.nn.relu(aff1)
    scores = tf.matmul(relu2, W2) + b2
    return scores
    

y_out = complex_model(X,y,is_training)

# %% [markdown]
# To make sure you're doing the right thing, use the following tool to check the dimensionality of your output (it should be 64 x 10, since our batches have size 64 and the output of the final affine layer should be 10, corresponding to our 10 classes):

# %%
# Now we're going to feed a random batch into the model 
# and make sure the output is the right size
x = np.random.randn(64, 32, 32,3)
with tf.Session() as sess:
    with tf.device("/gpu:0"): #"/cpu:0" or "/gpu:0"
        tf.global_variables_initializer().run()

        ans = sess.run(y_out,feed_dict={X:x,is_training:True})
        # %timeit sess.run(y_out,feed_dict={X:x,is_training:True})
        print(ans.shape)
        print(np.array_equal(ans.shape, np.array([64, 10])))
# Out:
# 100 loops, best of 3: 2.51 ms per loop
# (64, 10)
# True

# %% [markdown]
# You should see the following from the run above
#
# `(64, 10)`
#
# `True`

# %% [markdown]
# ### GPU!
#
# Now, we're going to try and start the model under the GPU device, the rest of the code stays unchanged and all our variables and operations will be computed using accelerated code paths. However, if there is no GPU, we get a Python exception and have to rebuild our graph. On a dual-core CPU, you might see around 50-80ms/batch running the above, while the Google Cloud GPUs (run below) should be around 2-5ms/batch.

# %%
try:
    with tf.Session() as sess:
        with tf.device("/gpu:0") as dev: #"/cpu:0" or "/gpu:0"
            tf.global_variables_initializer().run()

            ans = sess.run(y_out,feed_dict={X:x,is_training:True})
            # %timeit sess.run(y_out,feed_dict={X:x,is_training:True})
except tf.errors.InvalidArgumentError:
    print("no gpu found, please use Google Cloud if you want GPU acceleration")    
    # rebuild the graph
    # trying to start a GPU throws an exception 
    # and also trashes the original graph
    tf.reset_default_graph()
    X = tf.placeholder(tf.float32, [None, 32, 32, 3])
    y = tf.placeholder(tf.int64, [None])
    is_training = tf.placeholder(tf.bool)
    y_out = complex_model(X,y,is_training)
# Out:
# 100 loops, best of 3: 2.6 ms per loop

# %% [markdown]
# You should observe that even a simple forward pass like this is significantly faster on the GPU. So for the rest of the assignment (and when you go train your models in assignment 3 and your project!), you should use GPU devices. However, with TensorFlow, the default device is a GPU if one is available, and a CPU otherwise, so we can skip the device specification from now on.

# %% [markdown]
# ### Train the model.
#
# Now that you've seen how to define a model and do a single forward pass of some data through it, let's  walk through how you'd actually train one whole epoch over your training data (using the complex_model you created provided above).
#
# Make sure you understand how each TensorFlow function used below corresponds to what you implemented in your custom neural network implementation.
#
# First, set up an **RMSprop optimizer** (using a 1e-3 learning rate) and a **cross-entropy loss** function. See the TensorFlow documentation for more information
# * Layers, Activations, Loss functions : https://www.tensorflow.org/api_guides/python/nn
# * Optimizers: https://www.tensorflow.org/api_guides/python/train#Optimizers

# %%
# Inputs
#     y_out: is what your model computes
#     y: is your TensorFlow variable with label information
# Outputs
#    mean_loss: a TensorFlow variable (scalar) with numerical loss
#    optimizer: a TensorFlow optimizer
# This should be ~3 lines of code!
total_loss = tf.losses.softmax_cross_entropy(tf.one_hot(y, 10), logits=y_out)
mean_loss = tf.reduce_mean(total_loss)
optimizer = tf.train.RMSPropOptimizer(learning_rate=1e-3)
train_step = optimizer.minimize(mean_loss)

# %%
# batch normalization in tensorflow requires this extra dependency
extra_update_ops = tf.get_collection(tf.GraphKeys.UPDATE_OPS)
with tf.control_dependencies(extra_update_ops):
    train_step = optimizer.minimize(mean_loss)

# %% [markdown]
# ### Train the model
# Below we'll create a session and train the model over one epoch. You should see a loss of 1.4 to 2.0 and an accuracy of 0.4 to 0.5. There will be some variation due to random seeds and differences in initialization

# %%
sess = tf.Session()

sess.run(tf.global_variables_initializer())
print('Training')
run_model(sess,y_out,mean_loss,X_train,y_train,1,64,100,train_step)
# Out:
# Training
# Iteration 0: with minibatch training loss = 3.45 and accuracy of 0.078
# Iteration 100: with minibatch training loss = 2.79 and accuracy of 0.28
# Iteration 200: with minibatch training loss = 1.95 and accuracy of 0.36
# Iteration 300: with minibatch training loss = 1.61 and accuracy of 0.39
# Iteration 400: with minibatch training loss = 1.41 and accuracy of 0.5
# Iteration 500: with minibatch training loss = 1.5 and accuracy of 0.41
# Iteration 600: with minibatch training loss = 1.43 and accuracy of 0.53
# Iteration 700: with minibatch training loss = 1.1 and accuracy of 0.62
# Epoch 1, Overall loss = 1.7 and accuracy of 0.448
# (1.7002655808195777, 0.44820408163265307)

# %% [markdown]
# ### Check the accuracy of the model.
#
# Let's see the train and test code in action -- feel free to use these methods when evaluating the models you develop below. You should see a loss of 1.3 to 2.0 with an accuracy of 0.45 to 0.55.

# %%
print('Validation')
run_model(sess,y_out,mean_loss,X_val,y_val,1,64)
# Out:
# Validation
# Epoch 1, Overall loss = 1.4 and accuracy of 0.532
# (1.4011301536560059, 0.53200000000000003)

# %% [markdown]
# ## Train a _great_ model on CIFAR-10!
#
# Now it's your job to experiment with architectures, hyperparameters, loss functions, and optimizers to train a model that achieves ** >= 70% accuracy on the validation set** of CIFAR-10. You can use the `run_model` function from above.

# %% [markdown]
# ### Things you should try:
# - **Filter size**: Above we used 7x7; this makes pretty pictures but smaller filters may be more efficient
# - **Number of filters**: Above we used 32 filters. Do more or fewer do better?
# - **Pooling vs Strided Convolution**: Do you use max pooling or just stride convolutions?
# - **Batch normalization**: Try adding spatial batch normalization after convolution layers and vanilla batch normalization after affine layers. Do your networks train faster?
# - **Network architecture**: The network above has two layers of trainable parameters. Can you do better with a deep network? Good architectures to try include:
#     - [conv-relu-pool]xN -> [affine]xM -> [softmax or SVM]
#     - [conv-relu-conv-relu-pool]xN -> [affine]xM -> [softmax or SVM]
#     - [batchnorm-relu-conv]xN -> [affine]xM -> [softmax or SVM]
# - **Use TensorFlow Scope**: Use TensorFlow scope and/or [tf.layers](https://www.tensorflow.org/api_docs/python/tf/layers) to make it easier to write deeper networks. See [this tutorial](https://www.tensorflow.org/tutorials/layers) for how to use `tf.layers`.
# - **Use Learning Rate Decay**: [As the notes point out](http://cs231n.github.io/neural-networks-3/#anneal), decaying the learning rate might help the model converge. Feel free to decay every epoch, when loss doesn't change over an entire epoch, or any other heuristic you find appropriate. See the [Tensorflow documentation](https://www.tensorflow.org/versions/master/api_guides/python/train#Decaying_the_learning_rate) for learning rate decay.
# - **Global Average Pooling**: Instead of flattening and then having multiple affine layers, perform convolutions until your image gets small (7x7 or so) and then perform an average pooling operation to get to a 1x1 image picture (1, 1 , Filter#), which is then reshaped into a (Filter#) vector. This is used in [Google's Inception Network](https://arxiv.org/abs/1512.00567) (See Table 1 for their architecture).
# - **Regularization**: Add l2 weight regularization, or perhaps use [Dropout as in the TensorFlow MNIST tutorial](https://www.tensorflow.org/get_started/mnist/pros)
#
# ### Tips for training
# For each network architecture that you try, you should tune the learning rate and regularization strength. When doing this there are a couple important things to keep in mind:
#
# - If the parameters are working well, you should see improvement within a few hundred iterations
# - Remember the coarse-to-fine approach for hyperparameter tuning: start by testing a large range of hyperparameters for just a few training iterations to find the combinations of parameters that are working at all.
# - Once you have found some sets of parameters that seem to work, search more finely around these parameters. You may need to train for more epochs.
# - You should use the validation set for hyperparameter search, and we'll save the test set for evaluating your architecture on the best parameters as selected by the validation set.
#
# ### Going above and beyond
# If you are feeling adventurous there are many other features you can implement to try and improve your performance. You are **not required** to implement any of these; however they would be good things to try for extra credit.
#
# - Alternative update steps: For the assignment we implemented SGD+momentum, RMSprop, and Adam; you could try alternatives like AdaGrad or AdaDelta.
# - Alternative activation functions such as leaky ReLU, parametric ReLU, ELU, or MaxOut.
# - Model ensembles
# - Data augmentation
# - New Architectures
#   - [ResNets](https://arxiv.org/abs/1512.03385) where the input from the previous layer is added to the output.
#   - [DenseNets](https://arxiv.org/abs/1608.06993) where inputs into previous layers are concatenated together.
#   - [This blog has an in-depth overview](https://chatbotslife.com/resnets-highwaynets-and-densenets-oh-my-9bb15918ee32)
#
# If you do decide to implement something extra, clearly describe it in the "Extra Credit Description" cell below.
#
# ### What we expect
# At the very least, you should be able to train a ConvNet that gets at **>= 70% accuracy on the validation set**. This is just a lower bound - if you are careful it should be possible to get accuracies much higher than that! Extra credit points will be awarded for particularly high-scoring models or unique approaches.
#
# You should use the space below to experiment and train your network. The final cell in this notebook should contain the training and validation set accuracies for your final trained network.
#
# Have fun and happy training!

# %%
# Feel free to play with this cell

# Implementation of DenseNet with depth L=40 and growth rate k=12.
# No bottlenecking is used in dense blocks
depth = 40
growth_rate = 12
dense_blocks = 3
dense_blk_depth = int((depth - 4) / dense_blocks)
reg_scale = 1e-4
dropout_rate_g = 0.25

def densenet_model(features, labels, is_training):
    # Composite layer
    # Batch norm -> ReLU -> 3x3 Conv
    def bn_relu_conv(current, num_filters, kernel_size, use_dropout=False, dropout_rate=0.3):
        current = tf.layers.batch_normalization(current, axis=3, epsilon=1e-5,
                                               training=is_training, trainable=True)
        current = tf.nn.relu(current)
        current = tf.layers.conv2d(current, num_filters, kernel_size, padding='SAME',
                                   kernel_regularizer=tf.contrib.layers.l2_regularizer(scale=reg_scale))
        if use_dropout:
            current = tf.layers.dropout(current, dropout_rate, training=is_training)
        return current
    
    # Dense block
    def dense_block(input, layers, growth, use_dropout=False, dropout_rate=0.5):
        current = input
        features = input.get_shape().as_list()[3]
        for idx in range(layers):
            layer_out = bn_relu_conv(current, growth, kernel_size=3, 
                                     use_dropout=use_dropout, dropout_rate=dropout_rate)
            current = tf.concat([current, layer_out], axis=3)
            features += growth
        return current, features
    
    # Transition layer - dimensionality reduction
    # 1x1 Conv -> 2x2 average pool
    def transition(input):
        feature_size = input.get_shape().as_list()[3]
        current = bn_relu_conv(input, feature_size, kernel_size=1)
        current = tf.layers.average_pooling2d(current, 2, 2, padding='SAME')
        return current
    
    # Build up the graph
    # First layer is just convolution
    current = tf.layers.conv2d(features, 16, 3, padding='SAME',
                               kernel_regularizer=tf.contrib.layers.l2_regularizer(scale=reg_scale))
    
    # First dense block, input size = (N, 32, 32, 16)
    current, features = dense_block(current, dense_blk_depth, growth_rate, 
                                    use_dropout=True, dropout_rate=dropout_rate_g)
    # Transition layer, input size = (N, 32, 32, 16 + growth_rate * (dense_blk_depth - 1))
    # which is (N, 32, 32, 148)
    current = transition(current)
    
    # Second dense block, input size = (N, 16, 16, 148)
    current, features = dense_block(current, dense_blk_depth, growth_rate, 
                                    use_dropout=True, dropout_rate=dropout_rate_g)
    # Transition layer, input size = (N, 16, 16, 280)
    current = transition(current)
    
    # Third dense block, input size = (N, 8, 8, 280)
    current, features = dense_block(current, dense_blk_depth, growth_rate, 
                                    use_dropout=True, dropout_rate=dropout_rate_g)
    # Output = (N, 8, 8, 412)
    
    # Batch norm, ReLU, and 8x8 global avg pool to get final features
    current = tf.layers.batch_normalization(current, axis=3, epsilon=1e-5, training=is_training)
    current = tf.nn.relu(current)
    current = tf.layers.average_pooling2d(current, 8, 8)
    # Output = (N, 1, 1, 412)
    
    num_features = current.get_shape().as_list()[3]
    current = tf.reshape(current, [-1, num_features])
    # Fully-connected layer to get scores
    logits = tf.layers.dense(current, 10,
                             kernel_regularizer=tf.contrib.layers.l2_regularizer(scale=reg_scale))
    return logits

tf.reset_default_graph()

X = tf.placeholder(tf.float32, [None, 32, 32, 3])
y = tf.placeholder(tf.int64, [None])
learning_rate = tf.placeholder(tf.float32)
is_training = tf.placeholder(tf.bool)

y_out = densenet_model(X,y,is_training)

# Set up loss and optimizer

momentum = 0.9

total_loss = tf.losses.softmax_cross_entropy(tf.one_hot(y, 10), logits=y_out) + tf.losses.get_regularization_loss()
mean_loss = tf.reduce_mean(total_loss)
optimizer = tf.train.MomentumOptimizer(learning_rate, momentum, use_nesterov=True)
train_step = optimizer.minimize(mean_loss)

# batch normalization in tensorflow requires this extra dependency
extra_update_ops = tf.get_collection(tf.GraphKeys.UPDATE_OPS)
with tf.control_dependencies(extra_update_ops):
    train_step = optimizer.minimize(mean_loss)

# %%
def run_densenet(session, predict, loss_val, Xd, yd,
                 epochs=1, batch_size=64, print_every=100,
                 training=None, plot_losses=False):
    # have tensorflow compute accuracy
    correct_prediction = tf.equal(tf.argmax(predict,1), y)
    accuracy = tf.reduce_mean(tf.cast(correct_prediction, tf.float32))
    
    # shuffle indicies
    train_indicies = np.arange(Xd.shape[0])
    np.random.shuffle(train_indicies)

    training_now = training is not None
    
    # setting up variables we want to compute (and optimizing)
    # if we have a training function, add that to things we compute
    variables = [mean_loss,correct_prediction,accuracy]
    if training_now:
        variables[-1] = training
        
    # Set the initial learning rate
    lr = 0.1
    
    # counter 
    iter_cnt = 0
    for e in range(epochs):
        if e == int(epochs / 3):     lr = 0.01
        if e == int(2 * epochs / 3): lr = 0.001
        # keep track of losses and accuracy
        correct = 0
        losses = []
        # make sure we iterate over the dataset once
        for i in range(int(math.ceil(Xd.shape[0]/batch_size))):
            # generate indicies for the batch
            start_idx = (i*batch_size)%Xd.shape[0]
            idx = train_indicies[start_idx:start_idx+batch_size]
            
            # create a feed dictionary for this batch
            feed_dict = {X: Xd[idx,:],
                         y: yd[idx],
                         is_training: training_now,
                         learning_rate: lr}
            # get batch size
            actual_batch_size = yd[idx].shape[0]
            
            # have tensorflow compute loss and correct predictions
            # and (if given) perform a training step
            loss, corr, _ = session.run(variables,feed_dict=feed_dict)
            
            # aggregate performance stats
            losses.append(loss*actual_batch_size)
            correct += np.sum(corr)
            
            # print every now and then
            if training_now and (iter_cnt % print_every) == 0:
                print("Iteration {0}: with minibatch training loss = {1:.3g} and accuracy of {2:.2g}"
                      .format(iter_cnt,loss,np.sum(corr)/actual_batch_size))
            iter_cnt += 1
        total_correct = correct/Xd.shape[0]
        total_loss = np.sum(losses)/Xd.shape[0]
        print("Epoch {2}, Overall loss = {0:.3g} and accuracy of {1:.3g}"
              .format(total_loss,total_correct,e+1))
        if plot_losses:
            plt.plot(losses)
            plt.grid(True)
            plt.title('Epoch {} Loss'.format(e+1))
            plt.xlabel('minibatch number')
            plt.ylabel('minibatch loss')
            plt.show()
    return total_loss,total_correct

# %%
# Don't allocate all of the memory on the GPU
config = tf.ConfigProto()
config.gpu_options.allow_growth = True
max_epochs = 30
sess = tf.Session(config=config)

# Train!
sess.run(tf.global_variables_initializer())
print('Training')
run_densenet(sess, y_out, mean_loss, X_train, y_train, max_epochs, 64, 100, train_step, True)
print('Validation')
run_densenet(sess, y_out, mean_loss, X_val, y_val, 1, 64)
# Out:
# Training
# Iteration 0: with minibatch training loss = 2.4 and accuracy of 0.11
# Iteration 100: with minibatch training loss = 1.79 and accuracy of 0.33
# Iteration 200: with minibatch training loss = 1.58 and accuracy of 0.45
# Iteration 300: with minibatch training loss = 1.57 and accuracy of 0.5
# Iteration 400: with minibatch training loss = 1.53 and accuracy of 0.47
# Iteration 500: with minibatch training loss = 1.02 and accuracy of 0.69
# Iteration 600: with minibatch training loss = 1.32 and accuracy of 0.55
# Iteration 700: with minibatch training loss = 1.09 and accuracy of 0.64
# Epoch 1, Overall loss = 1.48 and accuracy of 0.49
# Iteration 800: with minibatch training loss = 1.25 and accuracy of 0.58
# Iteration 900: with minibatch training loss = 1.16 and accuracy of 0.66
# Iteration 1000: with minibatch training loss = 1.43 and accuracy of 0.55
# Iteration 1100: with minibatch training loss = 0.967 and accuracy of 0.67
# Iteration 1200: with minibatch training loss = 0.893 and accuracy of 0.72
# Iteration 1300: with minibatch training loss = 1.09 and accuracy of 0.7
# Iteration 1400: with minibatch training loss = 0.963 and accuracy of 0.66
# Iteration 1500: with minibatch training loss = 0.764 and accuracy of 0.77
# Epoch 2, Overall loss = 1.02 and accuracy of 0.669
# Iteration 1600: with minibatch training loss = 0.819 and accuracy of 0.75
# Iteration 1700: with minibatch training loss = 0.936 and accuracy of 0.7
# Iteration 1800: with minibatch training loss = 0.743 and accuracy of 0.83
# Iteration 1900: with minibatch training loss = 0.788 and accuracy of 0.77
# Iteration 2000: with minibatch training loss = 0.869 and accuracy of 0.69
# Iteration 2100: with minibatch training loss = 0.856 and accuracy of 0.69
# Iteration 2200: with minibatch training loss = 0.784 and accuracy of 0.78
# Epoch 3, Overall loss = 0.859 and accuracy of 0.735
# Iteration 2300: with minibatch training loss = 0.832 and accuracy of 0.77
# Iteration 2400: with minibatch training loss = 0.782 and accuracy of 0.78
# Iteration 2500: with minibatch training loss = 0.842 and accuracy of 0.75
# Iteration 2600: with minibatch training loss = 0.805 and accuracy of 0.7
# Iteration 2700: with minibatch training loss = 0.847 and accuracy of 0.75
# Iteration 2800: with minibatch training loss = 0.745 and accuracy of 0.77
# Iteration 2900: with minibatch training loss = 0.622 and accuracy of 0.81
# Iteration 3000: with minibatch training loss = 0.796 and accuracy of 0.8
# Epoch 4, Overall loss = 0.762 and accuracy of 0.774
# Iteration 3100: with minibatch training loss = 0.811 and accuracy of 0.77
# Iteration 3200: with minibatch training loss = 0.835 and accuracy of 0.73
# Iteration 3300: with minibatch training loss = 0.656 and accuracy of 0.83
# Iteration 3400: with minibatch training loss = 0.788 and accuracy of 0.75
# Iteration 3500: with minibatch training loss = 0.618 and accuracy of 0.81
# Iteration 3600: with minibatch training loss = 0.628 and accuracy of 0.83
# Iteration 3700: with minibatch training loss = 0.478 and accuracy of 0.89
# Iteration 3800: with minibatch training loss = 0.614 and accuracy of 0.83
# Epoch 5, Overall loss = 0.7 and accuracy of 0.799
# Iteration 3900: with minibatch training loss = 0.544 and accuracy of 0.84
# Iteration 4000: with minibatch training loss = 0.581 and accuracy of 0.78
# Iteration 4100: with minibatch training loss = 0.691 and accuracy of 0.78
# Iteration 4200: with minibatch training loss = 0.668 and accuracy of 0.86
# Iteration 4300: with minibatch training loss = 0.497 and accuracy of 0.89
# Iteration 4400: with minibatch training loss = 0.609 and accuracy of 0.8
# Iteration 4500: with minibatch training loss = 0.576 and accuracy of 0.88
# Epoch 6, Overall loss = 0.655 and accuracy of 0.818
# Iteration 4600: with minibatch training loss = 0.582 and accuracy of 0.88
# Iteration 4700: with minibatch training loss = 0.767 and accuracy of 0.88
# Iteration 4800: with minibatch training loss = 0.511 and accuracy of 0.88
# Iteration 4900: with minibatch training loss = 0.714 and accuracy of 0.77
# Iteration 5000: with minibatch training loss = 0.703 and accuracy of 0.83
# Iteration 5100: with minibatch training loss = 0.742 and accuracy of 0.84
# Iteration 5200: with minibatch training loss = 0.889 and accuracy of 0.72
# Iteration 5300: with minibatch training loss = 0.642 and accuracy of 0.84
# Epoch 7, Overall loss = 0.625 and accuracy of 0.832
# Iteration 5400: with minibatch training loss = 0.666 and accuracy of 0.84
# Iteration 5500: with minibatch training loss = 0.441 and accuracy of 0.91
# Iteration 5600: with minibatch training loss = 0.53 and accuracy of 0.86
# Iteration 5700: with minibatch training loss = 0.639 and accuracy of 0.88
# Iteration 5800: with minibatch training loss = 0.557 and accuracy of 0.84
# Iteration 5900: with minibatch training loss = 0.771 and accuracy of 0.81
# Iteration 6000: with minibatch training loss = 0.694 and accuracy of 0.8
# Iteration 6100: with minibatch training loss = 0.737 and accuracy of 0.75
# Epoch 8, Overall loss = 0.6 and accuracy of 0.843
# Iteration 6200: with minibatch training loss = 0.696 and accuracy of 0.84
# Iteration 6300: with minibatch training loss = 0.458 and accuracy of 0.86
# Iteration 6400: with minibatch training loss = 0.526 and accuracy of 0.88
# Iteration 6500: with minibatch training loss = 0.676 and accuracy of 0.8
# Iteration 6600: with minibatch training loss = 0.586 and accuracy of 0.84
# Iteration 6700: with minibatch training loss = 0.596 and accuracy of 0.86
# Iteration 6800: with minibatch training loss = 0.661 and accuracy of 0.83
# Epoch 9, Overall loss = 0.577 and accuracy of 0.855
# Iteration 6900: with minibatch training loss = 0.557 and accuracy of 0.84
# Iteration 7000: with minibatch training loss = 0.511 and accuracy of 0.88
# Iteration 7100: with minibatch training loss = 0.707 and accuracy of 0.84
# Iteration 7200: with minibatch training loss = 0.541 and accuracy of 0.83
# Iteration 7300: with minibatch training loss = 0.641 and accuracy of 0.84
# Iteration 7400: with minibatch training loss = 0.703 and accuracy of 0.83
# Iteration 7500: with minibatch training loss = 0.529 and accuracy of 0.89
# Iteration 7600: with minibatch training loss = 0.477 and accuracy of 0.92
# Epoch 10, Overall loss = 0.56 and accuracy of 0.862
# Iteration 7700: with minibatch training loss = 0.511 and accuracy of 0.91
# Iteration 7800: with minibatch training loss = 0.506 and accuracy of 0.89
# Iteration 7900: with minibatch training loss = 0.454 and accuracy of 0.92
# Iteration 8000: with minibatch training loss = 0.402 and accuracy of 0.95
# Iteration 8100: with minibatch training loss = 0.414 and accuracy of 0.89
# Iteration 8200: with minibatch training loss = 0.457 and accuracy of 0.89
# Iteration 8300: with minibatch training loss = 0.424 and accuracy of 0.91
# Iteration 8400: with minibatch training loss = 0.411 and accuracy of 0.94
# Epoch 11, Overall loss = 0.444 and accuracy of 0.906
# Iteration 8500: with minibatch training loss = 0.46 and accuracy of 0.95
# Iteration 8600: with minibatch training loss = 0.47 and accuracy of 0.89
# Iteration 8700: with minibatch training loss = 0.553 and accuracy of 0.88
# Iteration 8800: with minibatch training loss = 0.351 and accuracy of 0.94
# Iteration 8900: with minibatch training loss = 0.353 and accuracy of 0.92
# Iteration 9000: with minibatch training loss = 0.496 and accuracy of 0.91
# Iteration 9100: with minibatch training loss = 0.407 and accuracy of 0.92
# Epoch 12, Overall loss = 0.405 and accuracy of 0.919
# Iteration 9200: with minibatch training loss = 0.433 and accuracy of 0.88
# Iteration 9300: with minibatch training loss = 0.472 and accuracy of 0.86
# Iteration 9400: with minibatch training loss = 0.383 and accuracy of 0.97
# Iteration 9500: with minibatch training loss = 0.365 and accuracy of 0.94
# Iteration 9600: with minibatch training loss = 0.303 and accuracy of 0.95
# Iteration 9700: with minibatch training loss = 0.314 and accuracy of 0.94
# Iteration 9800: with minibatch training loss = 0.377 and accuracy of 0.92
# Iteration 9900: with minibatch training loss = 0.322 and accuracy of 0.94
# Epoch 13, Overall loss = 0.383 and accuracy of 0.926
# Iteration 10000: with minibatch training loss = 0.622 and accuracy of 0.81
# Iteration 10100: with minibatch training loss = 0.414 and accuracy of 0.92
# Iteration 10200: with minibatch training loss = 0.421 and accuracy of 0.89
# Iteration 10300: with minibatch training loss = 0.298 and accuracy of 0.94
# Iteration 10400: with minibatch training loss = 0.325 and accuracy of 0.94
# Iteration 10500: with minibatch training loss = 0.314 and accuracy of 0.95
# Iteration 10600: with minibatch training loss = 0.418 and accuracy of 0.94
# Iteration 10700: with minibatch training loss = 0.354 and accuracy of 0.92
# Epoch 14, Overall loss = 0.371 and accuracy of 0.928
# Iteration 10800: with minibatch training loss = 0.368 and accuracy of 0.94
# Iteration 10900: with minibatch training loss = 0.382 and accuracy of 0.92
# Iteration 11000: with minibatch training loss = 0.36 and accuracy of 0.94
# Iteration 11100: with minibatch training loss = 0.352 and accuracy of 0.92
# Iteration 11200: with minibatch training loss = 0.338 and accuracy of 0.92
# Iteration 11300: with minibatch training loss = 0.298 and accuracy of 0.95
# Iteration 11400: with minibatch training loss = 0.422 and accuracy of 0.89
# Epoch 15, Overall loss = 0.356 and accuracy of 0.934
# Iteration 11500: with minibatch training loss = 0.451 and accuracy of 0.92
# Iteration 11600: with minibatch training loss = 0.34 and accuracy of 0.91
# Iteration 11700: with minibatch training loss = 0.32 and accuracy of 0.94
# Iteration 11800: with minibatch training loss = 0.37 and accuracy of 0.95
# Iteration 11900: with minibatch training loss = 0.39 and accuracy of 0.94
# Iteration 12000: with minibatch training loss = 0.254 and accuracy of 0.95
# Iteration 12100: with minibatch training loss = 0.418 and accuracy of 0.89
# Iteration 12200: with minibatch training loss = 0.272 and accuracy of 0.95
# Epoch 16, Overall loss = 0.343 and accuracy of 0.938
# Iteration 12300: with minibatch training loss = 0.286 and accuracy of 0.97
# Iteration 12400: with minibatch training loss = 0.368 and accuracy of 0.94
# Iteration 12500: with minibatch training loss = 0.349 and accuracy of 0.94
# Iteration 12600: with minibatch training loss = 0.376 and accuracy of 0.94
# Iteration 12700: with minibatch training loss = 0.285 and accuracy of 0.97
# Iteration 12800: with minibatch training loss = 0.234 and accuracy of 0.98
# Iteration 12900: with minibatch training loss = 0.29 and accuracy of 0.95
# Iteration 13000: with minibatch training loss = 0.249 and accuracy of 0.95
# Epoch 17, Overall loss = 0.333 and accuracy of 0.941
# Iteration 13100: with minibatch training loss = 0.249 and accuracy of 0.97
# Iteration 13200: with minibatch training loss = 0.277 and accuracy of 0.95
# Iteration 13300: with minibatch training loss = 0.301 and accuracy of 0.97
# Iteration 13400: with minibatch training loss = 0.268 and accuracy of 0.95
# Iteration 13500: with minibatch training loss = 0.411 and accuracy of 0.91
# Iteration 13600: with minibatch training loss = 0.385 and accuracy of 0.91
# Iteration 13700: with minibatch training loss = 0.319 and accuracy of 0.94
# Epoch 18, Overall loss = 0.324 and accuracy of 0.943
# Iteration 13800: with minibatch training loss = 0.249 and accuracy of 0.97
# Iteration 13900: with minibatch training loss = 0.344 and accuracy of 0.92
# Iteration 14000: with minibatch training loss = 0.308 and accuracy of 0.95
# Iteration 14100: with minibatch training loss = 0.37 and accuracy of 0.94
# Iteration 14200: with minibatch training loss = 0.313 and accuracy of 0.97
# Iteration 14300: with minibatch training loss = 0.239 and accuracy of 0.98
# Iteration 14400: with minibatch training loss = 0.258 and accuracy of 0.95
# Iteration 14500: with minibatch training loss = 0.237 and accuracy of 0.97
# Epoch 19, Overall loss = 0.31 and accuracy of 0.947
# Iteration 14600: with minibatch training loss = 0.39 and accuracy of 0.92
# Iteration 14700: with minibatch training loss = 0.264 and accuracy of 0.97
# Iteration 14800: with minibatch training loss = 0.243 and accuracy of 0.97
# Iteration 14900: with minibatch training loss = 0.302 and accuracy of 0.97
# Iteration 15000: with minibatch training loss = 0.29 and accuracy of 0.95
# Iteration 15100: with minibatch training loss = 0.239 and accuracy of 0.97
# Iteration 15200: with minibatch training loss = 0.244 and accuracy of 0.98
# Iteration 15300: with minibatch training loss = 0.299 and accuracy of 0.95
# Epoch 20, Overall loss = 0.301 and accuracy of 0.949
# Iteration 15400: with minibatch training loss = 0.341 and accuracy of 0.92
# Iteration 15500: with minibatch training loss = 0.348 and accuracy of 0.91
# Iteration 15600: with minibatch training loss = 0.23 and accuracy of 0.98
# Iteration 15700: with minibatch training loss = 0.221 and accuracy of 0.97
# Iteration 15800: with minibatch training loss = 0.289 and accuracy of 0.94
# Iteration 15900: with minibatch training loss = 0.25 and accuracy of 0.97
# Iteration 16000: with minibatch training loss = 0.22 and accuracy of 0.97
# Epoch 21, Overall loss = 0.28 and accuracy of 0.957
# Iteration 16100: with minibatch training loss = 0.244 and accuracy of 0.97
# Iteration 16200: with minibatch training loss = 0.198 and accuracy of 1
# Iteration 16300: with minibatch training loss = 0.313 and accuracy of 0.95
# Iteration 16400: with minibatch training loss = 0.282 and accuracy of 0.97
# Iteration 16500: with minibatch training loss = 0.333 and accuracy of 0.94
# Iteration 16600: with minibatch training loss = 0.195 and accuracy of 1
# Iteration 16700: with minibatch training loss = 0.278 and accuracy of 0.97
# Iteration 16800: with minibatch training loss = 0.274 and accuracy of 0.94
# Epoch 22, Overall loss = 0.272 and accuracy of 0.96
# Iteration 16900: with minibatch training loss = 0.225 and accuracy of 0.97
# Iteration 17000: with minibatch training loss = 0.279 and accuracy of 0.92
# Iteration 17100: with minibatch training loss = 0.269 and accuracy of 0.95
# Iteration 17200: with minibatch training loss = 0.336 and accuracy of 0.95
# Iteration 17300: with minibatch training loss = 0.232 and accuracy of 0.95
# Iteration 17400: with minibatch training loss = 0.258 and accuracy of 0.95
# Iteration 17500: with minibatch training loss = 0.259 and accuracy of 0.97
# Iteration 17600: with minibatch training loss = 0.206 and accuracy of 0.98
# Epoch 23, Overall loss = 0.269 and accuracy of 0.962
# Iteration 17700: with minibatch training loss = 0.352 and accuracy of 0.94
# Iteration 17800: with minibatch training loss = 0.206 and accuracy of 0.98
# Iteration 17900: with minibatch training loss = 0.206 and accuracy of 1
# Iteration 18000: with minibatch training loss = 0.219 and accuracy of 0.97
# Iteration 18100: with minibatch training loss = 0.254 and accuracy of 0.98
# Iteration 18200: with minibatch training loss = 0.334 and accuracy of 0.94
# Iteration 18300: with minibatch training loss = 0.222 and accuracy of 1
# Epoch 24, Overall loss = 0.267 and accuracy of 0.962
# Iteration 18400: with minibatch training loss = 0.237 and accuracy of 0.98
# Iteration 18500: with minibatch training loss = 0.369 and accuracy of 0.89
# Iteration 18600: with minibatch training loss = 0.2 and accuracy of 1
# Iteration 18700: with minibatch training loss = 0.219 and accuracy of 0.97
# Iteration 18800: with minibatch training loss = 0.285 and accuracy of 0.95
# Iteration 18900: with minibatch training loss = 0.276 and accuracy of 0.95
# Iteration 19000: with minibatch training loss = 0.269 and accuracy of 0.94
# Iteration 19100: with minibatch training loss = 0.266 and accuracy of 0.97
# Epoch 25, Overall loss = 0.265 and accuracy of 0.962
# Iteration 19200: with minibatch training loss = 0.276 and accuracy of 0.95
# Iteration 19300: with minibatch training loss = 0.361 and accuracy of 0.89
# Iteration 19400: with minibatch training loss = 0.219 and accuracy of 0.98
# Iteration 19500: with minibatch training loss = 0.212 and accuracy of 0.97
# Iteration 19600: with minibatch training loss = 0.332 and accuracy of 0.92
# Iteration 19700: with minibatch training loss = 0.332 and accuracy of 0.94
# Iteration 19800: with minibatch training loss = 0.174 and accuracy of 1
# Iteration 19900: with minibatch training loss = 0.194 and accuracy of 1
# Epoch 26, Overall loss = 0.263 and accuracy of 0.963
# Iteration 20000: with minibatch training loss = 0.253 and accuracy of 0.97
# Iteration 20100: with minibatch training loss = 0.293 and accuracy of 0.94
# Iteration 20200: with minibatch training loss = 0.202 and accuracy of 0.98
# Iteration 20300: with minibatch training loss = 0.268 and accuracy of 0.97
# Iteration 20400: with minibatch training loss = 0.222 and accuracy of 0.98
# Iteration 20500: with minibatch training loss = 0.211 and accuracy of 1
# Iteration 20600: with minibatch training loss = 0.24 and accuracy of 0.98
# Epoch 27, Overall loss = 0.26 and accuracy of 0.964
# Iteration 20700: with minibatch training loss = 0.254 and accuracy of 0.97
# Iteration 20800: with minibatch training loss = 0.261 and accuracy of 0.97
# Iteration 20900: with minibatch training loss = 0.253 and accuracy of 0.95
# Iteration 21000: with minibatch training loss = 0.228 and accuracy of 1
# Iteration 21100: with minibatch training loss = 0.237 and accuracy of 0.98
# Iteration 21200: with minibatch training loss = 0.227 and accuracy of 0.98
# Iteration 21300: with minibatch training loss = 0.205 and accuracy of 1
# Iteration 21400: with minibatch training loss = 0.317 and accuracy of 0.92
# Epoch 28, Overall loss = 0.26 and accuracy of 0.964
# Iteration 21500: with minibatch training loss = 0.208 and accuracy of 1
# Iteration 21600: with minibatch training loss = 0.251 and accuracy of 0.97
# Iteration 21700: with minibatch training loss = 0.229 and accuracy of 0.97
# Iteration 21800: with minibatch training loss = 0.234 and accuracy of 0.97
# Iteration 21900: with minibatch training loss = 0.355 and accuracy of 0.92
# Iteration 22000: with minibatch training loss = 0.227 and accuracy of 0.97
# Iteration 22100: with minibatch training loss = 0.236 and accuracy of 0.97
# Iteration 22200: with minibatch training loss = 0.32 and accuracy of 0.95
# Epoch 29, Overall loss = 0.26 and accuracy of 0.965
# Iteration 22300: with minibatch training loss = 0.259 and accuracy of 0.95
# Iteration 22400: with minibatch training loss = 0.286 and accuracy of 0.92
# Iteration 22500: with minibatch training loss = 0.264 and accuracy of 0.95
# Iteration 22600: with minibatch training loss = 0.237 and accuracy of 0.97
# Iteration 22700: with minibatch training loss = 0.235 and accuracy of 0.98
# Iteration 22800: with minibatch training loss = 0.291 and accuracy of 0.94
# Iteration 22900: with minibatch training loss = 0.292 and accuracy of 0.94
# Epoch 30, Overall loss = 0.257 and accuracy of 0.965
# Validation
# Epoch 1, Overall loss = 0.551 and accuracy of 0.874
# (0.55124617147445676, 0.874)

# %%
# Test your model here, and make sure 
# the output of this cell is the accuracy
# of your best model on the training and val sets
# We're looking for >= 70% accuracy on Validation
print('Training')
run_densenet(sess,y_out,mean_loss,X_train,y_train,1,64)
print('Validation')
run_densenet(sess,y_out,mean_loss,X_val,y_val,1,64)
# Out:
# Training
# Epoch 1, Overall loss = 0.265 and accuracy of 0.959
# Validation
# Epoch 1, Overall loss = 0.551 and accuracy of 0.874
# (0.55124623012542728, 0.874)

# %% [markdown]
# ### Describe what you did here
# In this cell you should also write an explanation of what you did, any additional features that you implemented, and any visualizations or graphs that you make in the process of training and evaluating your network

# %% [markdown]
# ## DenseNet
#
# Based on this excellent paper: https://arxiv.org/abs/1608.06993
#
# DenseNet looks like this:
#
# <img src="https://cloud.githubusercontent.com/assets/8370623/17981496/fa648b32-6ad1-11e6-9625-02fdd72fdcd3.jpg">
#
# This is a deep DenseNet with 3 dense blocks. Each dense block looks like this:
#
# <img src="https://cloud.githubusercontent.com/assets/8370623/17981494/f838717a-6ad1-11e6-9391-f0906c80bc1d.jpg" width="480">
#
# This dense block has 5 layers and a growth rate $k$ of 4. Each dense block is composed of *composite layers*, which are in turn composed of:
# - Spatial batch normalization
# - ReLU nonlinearity
# - 3x3 convolution with stride 1 $k$ filters
#
# As data flows through the dense block, the output of each composite layer is concatenated to the input data. As a result, each composite layer is densely connected to all of the preceeding layers. This means that during backpropogation, the gradient does not diminish through these deep layers. A ResNet does this skip-connection with an identity:
#
# $$
# \begin{aligned}
#  x_l = H_l(x_{l-1}) + x_{l-1}
# \end{aligned}
# $$
#
# DenseNet connects *all* of the preceeding layers in the dense block to the next composite layer, which further improves information flow.
#
# $$
# \begin{aligned}
#  x_l = H_l([x_0, x_1, ..., x_{l-1}])
# \end{aligned}
# $$
#
# `tf.concat` is used to append the data to the fourth axis of the data tensor.
#
# ### This implementation
#
# I use 3 dense blocks, each with a growth rate of 12, which gives 36 total composite layers. Each dense block is separated by a transition layer consisting of:
# - Spatial batch normalization
# - ReLU
# - 1x1 convolution
# - 2x2 max-pooling with a stride of 2
# Each transition layer reduces the dimensionality of the input tensor by a factor of 2 in height and width.
#
# I also use a 25% dropout layer after each convolution to limit co-adaptation of features.
#
# The final layer is a global average pool to reduce the input down to an Nx1x1xk tensor, which then goes through a final affine layer to get 10 class scores.
#
# The network is trained like in the paper with Nesterov SGD, with momentum = 0.9. The initial learning rate is 0.1 and is divded by 10 at each 3rd of the training run.
#
# The original paper trains it for 300 epochs. 30 epochs gives ~87.4% accuracy on the validation dataset (as opposed to ~93% after 300 epochs), which is good enough for me.

# %% [markdown]
# ### Test Set - Do this only once
# Now that we've gotten a result that we're happy with, we test our final model on the test set. This would be the score we would achieve on a competition. Think about how this compares to your validation set accuracy.

# %%
print('Test')
run_model(sess,y_out,mean_loss,X_test,y_test,1,64)
# Out:
# Test
# Epoch 1, Overall loss = 0.603 and accuracy of 0.872
# (0.60319643507003784, 0.87190000000000001)

# %% [markdown]
# ## Going further with TensorFlow
#
# The next assignment will make heavy use of TensorFlow. You might also find it useful for your projects.

# %% [markdown]
# # Extra Credit Description
# If you implement any additional features for extra credit, clearly describe them here with pointers to any code in this or other files if applicable.
